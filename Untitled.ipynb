# %%
# %matplotlib inline
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys

# %%
import torch
import torch.nn as nn
from datasets import RoadsDatasetTrain, RoadsDatasetTest
import torch.utils.data as data
from model import UNet
from train import train
from torchvision import transforms
from PIL import Image
from predict import predict
from helpers import get_train_dataset
from helpers import get_train_set_bk
from helpers import get_large_patches

# %%
BATCH_SIZE = 1
EPOCHS = 1
LEARNING_RATE = 0.0001
CRITERION = nn.BCELoss()

# %%
train_data_dir = "./Datasets/training"
train_dataset = RoadsDatasetTrain(root_dir=train_data_dir)

train_dataloader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=True)

X, Y = get_train_dataset(train_data_dir)
print("X:", X.size())
print("Y:", Y.size())

# X = X.permute(0,1,4,2,3)
print(X.size())
# l=X.transpose(2,4)
# print(l.size())

im = transforms.ToPILImage()(X[0].numpy()).convert("RGB")
im
# Out:
# X: torch.Size([62500, 96, 96, 3])
# Y: torch.Size([62500, 96, 96, 1])
# torch.Size([62500, 96, 96, 3])
# <PIL.Image.Image image mode=RGB size=96x96 at 0x7FA2CCD2FE80>

# %%
import pandas as pd 
x_dim = 96
y_dim = 96
patch_size = 16

# load data
df = get_train_set_bk("./Datasets/training")

# pad images
df["padded_img"] = df.apply(lambda row : pad_image(row["image"],x_dim,y_dim),axis = 1)
df["padded_groundtruth"] = df.apply(lambda row : pad_image(row["groundtruth"],x_dim,y_dim),axis = 1)

# %%
#get x_dim x y_dim patches centered in patch_size x patch_size
def get_large_patches_2(image,padded_image,patch_size,x_dim,y_dim):
    patches=[]
    
    if len(image.shape)>2:
        sh,sw,sc = image.shape 
    else:
        sh,sw = image.shape
        sc = 1    


    for j in range(patch_size//2,sw,patch_size):
        for i in range(patch_size//2, sh, patch_size):
            patches.append(padded_image[i:i+y_dim, j:j+x_dim])
    return patches

# %%
# get groundtruth to train
Labels = df.apply(lambda row :get_large_patches_2(row["groundtruth"],row["padded_groundtruth"],patch_size,x_dim,y_dim),axis = 1).tolist()
Labels_torch = torch.from_numpy(np.asarray(Labels))

# %%
Labels_torch.size()
# Out:
# torch.Size([100, 625, 96, 96])

# %%
# get images to train
X = df.apply(lambda row :get_large_patches_2(row["image"],row["padded_img"],patch_size,x_dim,y_dim),axis = 1).tolist()
X_torch = torch.from_numpy(np.asarray(X))

# %%
X_torch.size()
# Out:
# torch.Size([100, 625, 96, 96, 3])

# %%
# example of how to print image
image = Image.fromarray(np.asarray(X[0][0]), 'RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=96x96 at 0x1EF66960288>

# %%
unet = UNet()
train(model=unet, dataloader=train_dataloader, epochs=EPOCHS, criterion=CRITERION)
# Out:
# torch.Size([1, 3, 400, 400])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-0d2355561f17> in <module>
#       1 unet = UNet()
# ----> 2 train(model=unet, dataloader=train_dataloader, epochs=EPOCHS, criterion=CRITERION)
#
# ~/Git/road-segmentation-vGK/Road-Segmentation/train.py in train(model, dataloader, epochs, criterion, model_weights)
#      16             optimizer.zero_grad()
#      17
# ---> 18             output = model(batch_images[0])
#      19
#      20             loss = criterion(
#
# ~/Environments/Python/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
# ...

# %%
# test_data_dir = "./Datasets/test_set_images"
# test_dataset = RoadsDatasetTest(root_dir=test_data_dir)

# test_dataloader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=False)

# predicted_masks = predict(unet, test_dataloader)
